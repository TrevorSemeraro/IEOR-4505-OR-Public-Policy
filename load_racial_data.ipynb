# %%
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join('racial_data', 'data.csv'))
df["ZIP Code"] = df["NAME"].str.split(" ").str[-1]
df[df["ZIP Code"] == "10001"]
# Out:
#            GEO_ID         NAME  P8_001N  P8_002N  P8_003N  P8_004N  P8_005N  \
# 1  860Z200US10001  ZCTA5 10001    32612    29742    17409     3691      131
#
#    P8_006N  P8_007N  P8_008N  ...  P8_064N  P8_065N  P8_066N  P8_067N  \
# 1     6403       57     2051  ...        0        0        0        0
#
#    P8_068N  P8_069N  P8_070N  P8_071N  Unnamed: 73  ZIP Code
# 1        0        0        0        0          NaN     10001
#
# [1 rows x 75 columns]
